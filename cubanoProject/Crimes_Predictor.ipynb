# %% [markdown]
# # Predicción de categorías delictivas

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Carga de datos

# %%
crimes_afluency_ft = pd.read_csv('./data_crimes_afluency_line_type.csv', 
                 sep=',', engine='python', encoding="UTF-8", index_col=False)

# %% [raw]
# crimes_afluency_ft = pd.read_csv('./data_crimes_afluency_no_zeros_line_type.csv',
#                  sep=',', engine='python', encoding="UTF-8", index_col=False)

# %%
crimes_afluency_ft.head(3)
# Out:
#   line        type  weekday  id_crime_category  afluency_distribution  \
# 0    1  Intermedia        1                  5           11130.083333
# 1    1  Intermedia        1                  6           11130.083333
# 2    1  Intermedia        1                  7           11130.083333
#
#    crime_frequency
# 0              1.0
# 1             10.0
# 2              0.0

# %%
crimes_afluency_ft.columns.values
# Out:
# array(['line', 'type', 'weekday', 'id_crime_category',
#        'afluency_distribution', 'crime_frequency'], dtype=object)

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# Establecemos columnas categóricas a codificar con OneHotEncoder, y por otro lado las numéricas que serán sometidas a reescalamiento

# %%
# Columnas categóricas a codificar con OneHotEncoder
categorical_cols = ['line', 'type', 'weekday', 'id_crime_category']

# Columnas numéricas a escalar con StandardScaler
numeric_cols = ['afluency_distribution']

# %% [markdown]
# Definimos pipeline con el preprocesamiento deseado

# %%
# Definir el preprocesamiento con ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(), categorical_cols),
        ('scaler', StandardScaler(), numeric_cols)
    ])

# %% [markdown]
# Filtramos dataset para categoría delictiva específica
# - 5: ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIOLENCIA
# - 6: DELITO DE BAJO IMPACTO
# - 7: ROBO DE VEHÍCULO CON Y SIN VIOLENCIA
# - 11: ROBO A NEGOCIO CON VIOLENCIA
# - 13: ROBO A PASAJERO A BORDO DEL METRO CON Y SIN VIOLENCIA

# %%
crimes_afluency_ft = crimes_afluency_ft[crimes_afluency_ft['id_crime_category'] == 6]

# %% [markdown]
# ## Training with 80% of data

# %%
target = 'crime_frequency'

# %%
X = crimes_afluency_ft.drop([target], axis = 1)
y = crimes_afluency_ft[target]

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
def regression_metrics(y_real, y_pred):
    mae = mean_absolute_error(y_real, y_pred)
    mse = mean_squared_error(y_real, y_pred)
    rmse = mean_squared_error(y_real, y_pred, squared=False)
    r2 = r2_score(y_real, y_pred)
    print("MAE:", mae)
    print("MSE:", mse)
    print("RMSE:", rmse)
    print("R²:", r2)

# %% [markdown]
# ## Regression models

# %% [markdown]
# ### MultiLayer Perceptron Regressor

# %%
from sklearn.neural_network import MLPRegressor

# %%
mlpr = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', MLPRegressor(activation = 'tanh', alpha = 0.0007, learning_rate_init = 0.0001, random_state=1, max_iter=500, verbose = True))
    ])

# %%
mlpr.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 10.39983813
# Iteration 2, loss = 8.35197502
# Iteration 3, loss = 7.06099972
# Iteration 4, loss = 6.19531408
# Iteration 5, loss = 5.55695458
# Iteration 6, loss = 5.07054044
# Iteration 7, loss = 4.70670686
# Iteration 8, loss = 4.44476394
# Iteration 9, loss = 4.26288071
# Iteration 10, loss = 4.14232031
# Iteration 11, loss = 4.06264491
# Iteration 12, loss = 4.00944943
# Iteration 364, loss = 2.70872869
# Iteration 365, loss = 2.70874125
# Iteration 366, loss = 2.70844283
# Iteration 367, loss = 2.70826782
# Iteration 368, loss = 2.70886256
# Iteration 369, loss = 2.70840065
# Iteration 370, loss = 2.70810353
# Iteration 371, loss = 2.70841275
# Iteration 372, loss = 2.70827333
# Iteration 373, loss = 2.70883580
# Iteration 374, loss = 2.70811051
# Iteration 375, loss = 2.70882374
# Iteration 376, loss = 2.70746832
# Iteration 377, loss = 2.70786610
# Iteration 378, loss = 2.70806515
# Iteration 379, loss = 2.70838161
# Iteration 380, loss = 2.70800973
# Iteration 381, loss = 2.70794759
# Iteration 382, loss = 2.70783232
# Iteration 383, loss = 2.70764681
# Iteration 384, loss = 2.70770076
# Iteration 385, loss = 2.70741778
# Iteration 386, loss = 2.70734981
# Iteration 387, loss = 2.70741548
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('onehot', OneHotEncoder(),
#                                                   ['line', 'type', 'weekday',
#                                                    'id_crime_category']),
#                                                  ('scaler', StandardScaler(),
#                                                   ['afluency_distribution'])])),
#                 ('regressor',
#                  MLPRegressor(activation='tanh', alpha=0.0007,
#                               learning_rate_init=0.0001, max_iter=500,
#                               random_state=1, verbose=True))])

# %%
y_pred = mlpr.predict(X_val)

# %%
regression_metrics(y_val, y_pred)
# Out:
# MAE: 1.5346818102959159
# MSE: 5.565966114570813
# RMSE: 2.359229983399417
# R²: 0.6462276215893921

# %% [markdown]
# ### SGD Regressor

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgdr = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', SGDRegressor(max_iter=1000, tol=1e-3))
    ])

# %%
sgdr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('onehot', OneHotEncoder(),
#                                                   ['line', 'type', 'weekday',
#                                                    'id_crime_category']),
#                                                  ('scaler', StandardScaler(),
#                                                   ['afluency_distribution'])])),
#                 ('regressor', SGDRegressor())])

# %%
y_pred = sgdr.predict(X_val)

# %%
regression_metrics(y_val, y_pred)
# Out:
# MAE: 2.0410096284762145
# MSE: 7.979481634855251
# RMSE: 2.8247976272390294
# R²: 0.49282476063651337

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', GradientBoostingRegressor(random_state=0))
    ])

# %%
gbr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('onehot', OneHotEncoder(),
#                                                   ['line', 'type', 'weekday',
#                                                    'id_crime_category']),
#                                                  ('scaler', StandardScaler(),
#                                                   ['afluency_distribution'])])),
#                 ('regressor', GradientBoostingRegressor(random_state=0))])

# %%
y_pred = gbr.predict(X_val)

# %%
regression_metrics(y_val, y_pred)
# Out:
# MAE: 1.579872727124761
# MSE: 5.763568150831782
# RMSE: 2.4007432496691066
# R²: 0.6336680513534507

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', RandomForestRegressor(max_depth=None, random_state=0))
    ])

# %%
rfr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('onehot', OneHotEncoder(),
#                                                   ['line', 'type', 'weekday',
#                                                    'id_crime_category']),
#                                                  ('scaler', StandardScaler(),
#                                                   ['afluency_distribution'])])),
#                 ('regressor', RandomForestRegressor(random_state=0))])

# %%
y_pred = rfr.predict(X_val)

# %%
regression_metrics(y_val, y_pred)
# Out:
# MAE: 1.6563728772244866
# MSE: 6.548465884143069
# RMSE: 2.55899704652879
# R²: 0.5837800117558469

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR

# %%
svr = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', SVR(kernel='rbf'))
    ])

# %%
svr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('onehot', OneHotEncoder(),
#                                                   ['line', 'type', 'weekday',
#                                                    'id_crime_category']),
#                                                  ('scaler', StandardScaler(),
#                                                   ['afluency_distribution'])])),
#                 ('regressor', SVR())])

# %%
y_pred = svr.predict(X_val)

# %%
regression_metrics(y_val, y_pred)
# Out:
# MAE: 1.5006908728970973
# MSE: 5.671840022329213
# RMSE: 2.3815625169894687
# R²: 0.6394982841503332

# %% [markdown]
# ## Validación de resultados con el mejor modelo

# %%
from tabulate import tabulate

# %%
y_val_preds = gbr.predict(X_val)

# %%
res = list()
for i in range(len(y_val_preds)):
    y_pred = y_val_preds[i]
    y_real = y_val.iloc[i]
    error = abs(y_pred - y_real)
    res.append([round(y_real, 2), round(y_pred, 2), round(error, 2)])

# %%
print(tabulate(res, headers = ['Real y', 'Predicted y', 'Abs. Error'], tablefmt = 'fancy_grid', numalign = 'center'))
# Out:
# ╒══════════╤═══════════════╤══════════════╕
# │  Real y  │  Predicted y  │  Abs. Error  │
# ╞══════════╪═══════════════╪══════════════╡
# │    0     │     1.11      │     1.11     │
# ├──────────┼───────────────┼──────────────┤
# │    7     │     6.35      │     0.65     │
# ├──────────┼───────────────┼──────────────┤
# │    16    │     13.54     │     2.46     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     3.18      │     3.18     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     8.48      │     6.48     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     1.08      │     0.92     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     4.74      │     3.74     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     2.22      │     0.22     │
# ├──────────┼───────────────┼──────────────┤
# │    11    │     9.18      │     1.82     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.34      │     0.34     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │      0.6      │     0.6      │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.38      │     0.62     │
# ├──────────┼───────────────┼──────────────┤
# │    6     │     6.01      │     0.01     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     3.68      │     1.68     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.86      │     0.86     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.54      │     0.54     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.01      │     0.99     │
# ├──────────┼───────────────┼──────────────┤
# │    4     │     4.01      │     0.01     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │      4.5      │     4.5      │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     -0.01     │     0.01     │
# ├──────────┼───────────────┼──────────────┤
# │    5     │     7.56      │     2.56     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.76      │     0.24     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     0.68      │     2.32     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     1.07      │     0.07     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.86      │     0.14     │
# ├──────────┼───────────────┼──────────────┤
# │    8     │      3.3      │     4.7      │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     1.88      │     0.88     │
# ├──────────┼───────────────┼──────────────┤
# │    4     │     3.66      │     0.34     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.82      │     0.82     │
# ├──────────┼───────────────┼──────────────┤
# │    26    │     12.14     │    13.86     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     1.76      │     0.76     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.44      │     0.56     │
# ├──────────┼───────────────┼──────────────┤
# │    11    │     8.13      │     2.87     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     0.38      │     1.62     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     4.34      │     4.34     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.48      │     0.48     │
# ├──────────┼───────────────┼──────────────┤
# │    10    │     5.06      │     4.94     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     0.87      │     2.13     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.82      │     0.18     │
# ├──────────┼───────────────┼──────────────┤
# │    10    │     12.6      │     2.6      │
# ├──────────┼───────────────┼──────────────┤
# │    7     │     8.23      │     1.23     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     1.26      │     0.26     │
# ├──────────┼───────────────┼──────────────┤
# │    4     │     3.13      │     0.87     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │       4       │      2       │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     2.45      │     2.45     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.79      │     0.79     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     3.97      │     1.97     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.35      │     0.65     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     3.52      │     1.52     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     2.93      │     0.07     │
# ├──────────┼───────────────┼──────────────┤
# │    6     │     4.74      │     1.26     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     1.93      │     1.07     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     7.59      │     7.59     │
# ├──────────┼───────────────┼──────────────┤
# │    4     │       4       │      0       │
# ├──────────┼───────────────┼──────────────┤
# │    13    │     7.63      │     5.37     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     5.84      │     2.84     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.03      │     0.03     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     -0.32     │     0.32     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.86      │     0.86     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │      4.5      │     2.5      │
# ├──────────┼───────────────┼──────────────┤
# │    6     │     3.96      │     2.04     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │

# ├──────────┼───────────────┼──────────────┤
# │    0     │      0.7      │     0.7      │
# ├──────────┼───────────────┼──────────────┤
# │    5     │     5.78      │     0.78     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     0.62      │     1.38     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     3.79      │     0.79     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     0.87      │     1.13     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.44      │     0.56     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.56      │     0.56     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.86      │     0.86     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.16      │     0.84     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     4.44      │     3.44     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     2.78      │     0.78     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     0.59      │     1.41     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.67      │     0.67     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     2.22      │     0.78     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     2.37      │     2.37     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.87      │     0.87     │
# ├──────────┼───────────────┼──────────────┤
# │    15    │     8.91      │     6.09     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.82      │     0.82     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.52      │     0.52     │
# ├──────────┼───────────────┼──────────────┤
# │    10    │     7.96      │     2.04     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.12      │     0.12     │
# ├──────────┼───────────────┼──────────────┤
# │    7     │     8.86      │     1.86     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     3.49      │     0.49     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     -0.11     │     0.11     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.69      │     0.31     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     1.42      │     1.42     │
# ├──────────┼───────────────┼──────────────┤
# │    9     │     6.47      │     2.53     │
# ├──────────┼───────────────┼──────────────┤
# │    10    │     4.64      │     5.36     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     0.82      │     1.18     │
# ├──────────┼───────────────┼──────────────┤
# │    9     │     5.06      │     3.94     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.58      │     0.42     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │      0.7      │     0.3      │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     0.85      │     2.15     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.05      │     0.95     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.66      │     0.66     │
# ├──────────┼───────────────┼──────────────┤
# │    16    │     14.1      │     1.9      │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     1.38      │     1.38     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.71      │     0.71     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.61      │     0.61     │
# ├──────────┼───────────────┼──────────────┤
# │    8     │     7.21      │     0.79     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.86      │     0.86     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     -0.11     │     0.11     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.41      │     0.41     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     1.97      │     1.97     │
# ├──────────┼───────────────┼──────────────┤
# │    4     │     2.24      │     1.76     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     3.59      │     3.59     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.71      │     0.71     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     3.26      │     0.26     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.58      │     0.58     │
# ├──────────┼───────────────┼──────────────┤
# │    7     │     3.84      │     3.16     │
# ├──────────┼───────────────┼──────────────┤
# │    5     │     2.84      │     2.16     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     3.09      │     1.09     │
# ├──────────┼───────────────┼──────────────┤
# │    4     │     2.73      │     1.27     │
# ├──────────┼───────────────┼──────────────┤
# │    5     │     3.15      │     1.85     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     1.96      │     0.96     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.67      │     0.33     │
# ├──────────┼───────────────┼──────────────┤
# │    6     │     3.87      │     2.13     │
# ├──────────┼───────────────┼──────────────┤
# │    7     │     6.02      │     0.98     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     0.79      │     0.79     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     1.95      │     0.95     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     0.98      │     2.02     │
# ├──────────┼───────────────┼──────────────┤
# │    5     │     4.02      │     0.98     │
# ├──────────┼───────────────┼──────────────┤
# │    5     │     3.17      │     1.83     │
# ├──────────┼───────────────┼──────────────┤
# │    8     │     8.79      │     0.79     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     2.56      │     1.56     │
# ├──────────┼───────────────┼──────────────┤
# │    8     │     10.26     │     2.26     │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     0.42      │     0.58     │
# ├──────────┼───────────────┼──────────────┤
# │    4     │     3.02      │     0.98     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │      0.3      │     0.3      │
# ├──────────┼───────────────┼──────────────┤
# │    1     │     1.01      │     0.01     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     1.05      │     1.05     │
# ├──────────┼───────────────┼──────────────┤
# │    7     │     7.18      │     0.18     │
# ├──────────┼───────────────┼──────────────┤
# │    5     │     4.53      │     0.47     │
# ├──────────┼───────────────┼──────────────┤
# │    3     │     1.15      │     1.85     │
# ├──────────┼───────────────┼──────────────┤
# │    0     │     1.23      │     1.23     │
# ├──────────┼───────────────┼──────────────┤
# │    2     │     3.54      │     1.54     │
# ╘══════════╧═══════════════╧══════════════╛

# %% [markdown]
# ## Simulating data

# %%
line_values = crimes_afluency_ft.line.unique()
type_station_values = crimes_afluency_ft.type.unique()
weekday_values = crimes_afluency_ft.weekday.unique()
crime_category_values = crimes_afluency_ft.id_crime_category.unique()
afluency_dist_values = crimes_afluency_ft.afluency_distribution.unique()

# %%
def random_sample(arr):
    return np.random.choice(arr)

# %%
def simulated_data(unique_values, col_names, n = 50):
    data = [[random_sample(arr) for arr in unique_values] for i in range(n)]
    return pd.DataFrame(data, columns = col_names)

# %%
unique_values = [line_values, type_station_values, weekday_values, crime_category_values, afluency_dist_values]

# %%
features_names = list(crimes_afluency_ft.columns)[:-1]
features_names
# Out:
# ['line', 'type', 'weekday', 'id_crime_category', 'afluency_distribution']

# %%
simulated_df = simulated_data(unique_values, features_names, n = 100)

# %%
simulated_df
# Out:
#    line                   type  weekday  id_crime_category  \
# 0     1               Terminal        0                  6
# 1     8  Terminal / Transbordo        1                  6
# 2     A               Terminal        3                  6
# 3     A               Terminal        1                  6
# 4     4               Terminal        2                  6
# ..  ...                    ...      ...                ...
# 95    7  Terminal / Transbordo        2                  6
# 96    A             Transbordo        2                  6
# 97    8               Terminal        4                  6
# 98    9             Transbordo        6                  6
# 99    7  Terminal / Transbordo        0                  6
#
#     afluency_distribution
# 0            20988.166667
# 1             6991.000000
# 2            16206.000000
# 3            11810.500000
# 4            34746.000000
# ..                    ...
# 95           13366.000000
# 96           13551.000000
# 97            8374.000000
# 98            4352.666667
# 99           29856.166667
#
# [100 rows x 5 columns]

# %%
y_sim_preds = gbr.predict(simulated_df)

# %%
simulated_df_preds = pd.concat([simulated_df, pd.Series(y_sim_preds, name = 'pred_crime_frequency')], axis = 1)

# %%
simulated_df_preds[(simulated_df_preds['line'] == '2')]
# Out:
#    line        type  weekday  id_crime_category  afluency_distribution  \
# 6     2  Transbordo        6                  6            7666.714286
# 9     2    Terminal        5                  6           27045.000000
# 23    2  Transbordo        2                  6           30984.250000
# 82    2  Intermedia        5                  6           18352.166667
# 87    2  Transbordo        5                  6           28831.333333
#
#     pred_crime_frequency
# 6               4.230584
# 9               0.221582
# 23              8.786630
# 82             12.073677
# 87              8.379680

# %%
validation_df_preds = pd.concat([X_val.reset_index(), pd.Series(y_val_preds, name = 'pred_crime_frequency')], axis = 1)

# %%
validation_df_preds[(validation_df_preds['line'] == '2')]
# Out:
#        index line        type  weekday  id_crime_category  \
# 2      68041    2  Intermedia        5                  6
# 12    143651    2  Transbordo        5                  6
# 29    203641    2  Intermedia        4                  6
# 52    214251    2  Transbordo        1                  6
# 157   149051    2  Transbordo        4                  6
# ...      ...  ...         ...      ...                ...
# 8679   80246    2    Terminal        3                  6
# 8710    5846    2    Terminal        2                  6
# 8711   51251    2  Transbordo        5                  6
# 8727   19641    2  Intermedia        1                  6
# 8755   85651    2  Transbordo        2                  6
#
#       afluency_distribution  pred_crime_frequency
# 2              26160.625000             13.544258
# 12             15677.000000              6.011029
# 29             13698.312500             12.142034
# 52             18296.833333              7.587454
# 157                0.000000              5.339413
# ...                     ...                   ...
# 8679           92905.500000              0.522069
# 8710          104438.000000              0.522069
# 8711           27386.000000              7.959806
# 8727           28233.375000             14.097487
# 8755           29570.333333              8.786630
#
# [606 rows x 7 columns]

# %% [markdown]
# ## Export model

# %%
import pickle

# %%
with open('crimes_regressor.pkl', 'wb') as f:
    pickle.dump(gbr, f)
